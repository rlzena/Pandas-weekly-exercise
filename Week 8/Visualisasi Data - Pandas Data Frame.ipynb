# %% [markdown]
# Visualisasi Data - Pandas Data Frame
#
# Link youtube : https://www.youtube.com/watch?v=62fvkpR_b8s&authuser=0

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.0.3
# 1.24.3

# %%
n_rows = 40
n_cols = 5
cols = tuple ('ABCDE')

df = pd.DataFrame(np.random.randint(1,20,size=(n_rows, n_cols)),
                  columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0   7  14   1   9  19
# 1   9   8  18  13   3
# 2  17   7  18  10   5
# 3  19  18  16  12  10
# 4   6  10  11   8  10

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   7  14   1   9  19
# 1   9   8  18  13   3
# 2  17   7  18  10   5
# 3  19  18  16  12  10
# 4   6  10  11   8  10

# %%
df.plot(kind='line')
# Out:
# <Axes: >

# %%
df[['A','B']].plot(kind='line')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   7  14   1   9  19
# 1   9   8  18  13   3
# 2  17   7  18  10   5
# 3  19  18  16  12  10
# 4   6  10  11   8  10

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df[['A','B']].plot(kind='bar')
# Out:
# <Axes: >

# %%
df[['A','B']].head().plot(kind='bar')
# Out:
# <Axes: >

# %%
df[['A','B']].head().plot(kind='barh')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   7  14   1   9  19
# 1   9   8  18  13   3
# 2  17   7  18  10   5
# 3  19  18  16  12  10
# 4   6  10  11   8  10

# %%
df.plot(kind='area')
# Out:
# <Axes: >

# %%
df[['A','B']].head().plot(kind='area')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   7  14   1   9  19
# 1   9   8  18  13   3
# 2  17   7  18  10   5
# 3  19  18  16  12  10
# 4   6  10  11   8  10

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   7  14   1   9  19
# 1   9   8  18  13   3
# 2  17   7  18  10   5
# 3  19  18  16  12  10
# 4   6  10  11   8  10

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['A','B']].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   7  14   1   9  19
# 1   9   8  18  13   3
# 2  17   7  18  10   5
# 3  19  18  16  12  10
# 4   6  10  11   8  10

# %%
df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   7  14   1   9  19
# 1   9   8  18  13   3
# 2  17   7  18  10   5
# 3  19  18  16  12  10
# 4   6  10  11   8  10

# %%
df.plot(x='A', y='B', kind='scatter')
# Out:
# <Axes: xlabel='A', ylabel='B'>
