# %% [markdown]
# Membuat kolom baru dengan for loop dan f-string
#
# Link youtube : https://www.youtube.com/watch?v=6i5OQ_F3x7A&authuser=0

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.0.3

# %%
d = {'penjual' :['bejo', 'tejo', 'wati', 'bejo', 'cecep', 'tejo', 'wati', 'bejo'],
     'barang' :['monitor', 'monitor', 'keyboard', 'mouse', 'keyboard', 'monitor', 'laptop', 'monitor']}

df = pd.DataFrame(d)
df
# Out:
#   penjual    barang
# 0    bejo   monitor
# 1    tejo   monitor
# 2    wati  keyboard
# 3    bejo     mouse
# 4   cecep  keyboard
# 5    tejo   monitor
# 6    wati    laptop
# 7    bejo   monitor

# %%
cols = ['penjual', 'barang']

for col in cols:
    df[f'count_tiap_{col}'] = df.groupby(col).cumcount() + 1
    
df
# Out:
#   penjual    barang  count_tiap penjual  count_tiap barang  \
# 0    bejo   monitor                   1                  1
# 1    tejo   monitor                   1                  2
# 2    wati  keyboard                   1                  1
# 3    bejo     mouse                   2                  1
# 4   cecep  keyboard                   1                  2
# 5    tejo   monitor                   2                  3
# 6    wati    laptop                   2                  1
# 7    bejo   monitor                   3                  4
#
#    count_tiap_penjual  count_tiap_barang
# 0                   1                  1
# 1                   1                  2
# 2                   1                  1
# 3                   2                  1
# 4                   1                  2
# 5                   2                  3
# 6                   2                  1
# 7                   3                  4
